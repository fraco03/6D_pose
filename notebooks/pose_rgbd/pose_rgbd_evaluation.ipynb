# %%
path = "./RGBD_final/RGBD_final/"

model_path = path + "best_model.pth"

# %%
# %pwd
# Out:
# 'f:\\Magistrale\\Advanced Machine Learning\\6D_pose\\notebooks\\pose_rgbd'

# %%
import sys
sys.path.append('../..')

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
from src.pose_rgbd.model import RotationPredictionModel


data = torch.load(model_path, map_location=device)
model = RotationPredictionModel()
model.load_state_dict(data['model_state_dict'])
model
# Out:
# RotationPredictionModel(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
from src.pose_rgbd.dataset import LineModPoseDepthDataset

dataset_root = "../../Linemod_preprocessed"

test_dataset = LineModPoseDepthDataset(
    root_dir=dataset_root,
    split="test"
)
# Out:
# ✅ LineModConfig initialized: F:\Magistrale\Advanced Machine Learning\6D_pose\Linemod_preprocessed
#  Loaded LineModPoseDepthDataset
#    Split: test
#    Objects: [1, 2, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 15]
#    Total samples: 20528

# %%
from src.pose_rgbd.evaluation import evaluate_RGBD_model

evaluate_RGBD_model(
    model,
    test_dataset,  # Usa dataset direttamente, non DataLoader
    device,
    dataset_root=dataset_root,
    save_results_dir="results_eval"
)
# Out:
# 📦 Pre-loading model data...
#   ✅ Object 1: 5841 points, diameter=102.1mm
#   ✅ Object 2: 38325 points, diameter=247.5mm
#   ✅ Object 4: 18995 points, diameter=172.5mm
#   ✅ Object 5: 22831 points, diameter=201.4mm
#   ✅ Object 6: 15736 points, diameter=154.5mm
#   ✅ Object 8: 12655 points, diameter=261.5mm
#   ✅ Object 9: 7912 points, diameter=109.0mm
#   ✅ Object 10: 18473 points, diameter=164.6mm
#   ✅ Object 11: 7479 points, diameter=175.9mm
#   ✅ Object 12: 15972 points, diameter=145.5mm
#   ✅ Object 13: 18216 points, diameter=278.1mm
#   ✅ Object 14: 27435 points, diameter=282.6mm
#   ✅ Object 15: 16559 points, diameter=212.4mm
# 🚀 Starting evaluation...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 3
#       1 from src.pose_rgbd.evaluation import evaluate_RGBD_model
# ----> 3 evaluate_RGBD_model(
#       4     model,
# ...
