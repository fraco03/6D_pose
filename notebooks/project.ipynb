# %%
# 🚀 Setup: Clone repository and mount drive
# !git clone -b DriveMounting https://github.com/fraco03/6D_pose.git

print("✅ Repository cloned successfully")

# Mount Google Drive (only on Colab)
from google.colab import drive
drive.mount('/content/drive')

# Add repository to Python path
import sys
if '/content/6D_pose' not in sys.path:
    sys.path.insert(0, '/content/6D_pose')

if '/content/6D_pose/src' not in sys.path:
    sys.path.insert(0, '/content/6D_pose/src')
    
# Install dependencies
# %cd 6D_pose
# !pip install -r requirements.txt

from utils.load_data import mount_drive

mount_drive()
dataset_root = "/content/drive/MyDrive/Linemod_preprocessed"


print("\n✅ Setup complete!")
print(f"📁 Dataset path: {dataset_root}")
# Out:
# Cloning into '6D_pose'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 90 (delta 39), reused 61 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (90/90), 1.60 MiB | 10.64 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# ✅ Repository cloned successfully
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/6D_pose
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ✅ Drive mounted at /content/drive/Linemod_preprocessed
#
# ✅ Setup complete!
# 📁 Dataset path: /content/drive/Linemod_preprocessed

# %%
# %ls drive
# Out:
# MyDrive/

# %% [markdown]
# # Yolo

# %% [markdown]
# # Resnet
