# %%
# 🚀 Setup: Clone repository and mount drive
# !git clone https://github.com/fraco03/6D_pose.git

# Mount Google Drive (only on Colab)
from google.colab import drive
drive.mount('/content/drive')

# Add repository to Python path
import sys
sys.path.insert(0, '/content/6D_pose')

# Install dependencies
# %cd 6D_pose
# !pip install -r requirements.txt

# Verify imports
from src.pose_rgb.dataset import LineModPoseDataset
from src.pose_rgb.model import ResNetQuaternion
from src.pose_rgb.loss import PoseLoss
from utils.load_data import DATASET_PATH

print("\n✅ Setup complete!")
print(f"📁 Dataset path: {DATASET_PATH}")
